# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv(r"C:\Users\manasbhatnagar\Downloads\bostonhousing.csv")

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
df=df.drop(columns=["Unnamed: 0"])
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # EDA

# %%
sb.distplot(df["crim"])

# %%
sb.distplot(df["zn"])

# %%
sb.distplot(df["indus"])

# %%
sb.distplot(df["chas"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-62-8be577557472> in <module>
# ----> 1 sb.distplot(df["chas"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
sb.distplot(df["nox"])

# %%
sb.distplot(df["rm"])

# %%
sb.distplot(df["age"])

# %%
sb.distplot(df["dis"])

# %%
sb.distplot(df["rad"])

# %%
sb.distplot(df["tax"])

# %%
sb.distplot(df['ptratio'])

# %%
sb.distplot(df['black'])

# %%
sb.distplot(df['lstat'])

# %%
sb.distplot(df["medv"])

# %%
sb.scatterplot(x="zn",y="medv",data=df)

# %%
sb.scatterplot(x="chas",y="medv",data=df)

# %%
sb.scatterplot(x="rad",y="medv",data=df)

# %%
sb.scatterplot(x="tax",y="medv",data=df)

# %%
sb.pairplot(df)

# %% [markdown]
# # Feature Engineering

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
sb.distplot(df["lstat"])

# %%
df["lstat_sqrt"]=df["lstat"]**(1/2)

# %%
sb.distplot(df["lstat_sqrt"])

# %%
sb.distplot(df['ptratio'])

# %%
df["ptratio_log"]=np.log(df["ptratio"])

# %%
sb.distplot(df["ptratio_log"])

# %%
sb.distplot(df["indus"])

# %%
df["indus_inverse"]=1/df["indus"]

# %%
sb.distplot(df["indus_inverse"])

# %%
sb.distplot(df["nox"])

# %%
df["nox_inverse"]=1/df["nox"]

# %%
sb.distplot(df["nox_inverse"])

# %%
df["crim_sqrt"]=df["crim"]**(1/2)

# %%
sb.distplot(df["crim_sqrt"])

# %%
df1=df.drop(columns=["crim","indus","nox","ptratio","lstat"])

# %% [markdown]
# # Outlier Detection & Removal

# %%
rm_mean=df1["rm"].mean()
rm_mean
# Out:
# 6.284634387351788

# %%
rm_std=df1["rm"].std()
rm_std
# Out:
# 0.7026171434153234

# %%
age_mean=df1["age"].mean()
age_mean
# Out:
# 68.57490118577078

# %%
age_std=df1["age"].std()
age_std
# Out:
# 28.148861406903638

# %%
dis_mean=df1["dis"].mean()
dis_mean
# Out:
# 3.795042687747034

# %%
dis_std=df1["dis"].std()
dis_std
# Out:
# 2.1057101266276104

# %%
black_mean=df1["black"].mean()
black_mean
# Out:
# 356.67403162055257

# %%
black_std=df1["black"].std()
black_std
# Out:
# 91.29486438415779

# %%
crim_mean=df1["crim_sqrt"].mean()
crim_mean
# Out:
# 1.2294394198092045

# %%
crim_std=df1["crim_sqrt"].std()
crim_std
# Out:
# 1.4512631226158779

# %%
indus_mean=df1["indus_inverse"].mean()
indus_mean
# Out:
# 0.16263141886673582

# %%
indus_std=df1["indus_inverse"].std()
indus_std
# Out:
# 0.1776458174936309

# %%
nox_mean=df1["nox_inverse"].mean()
nox_mean
# Out:
# 1.8771452603098617

# %%
nox_std=df1["nox_inverse"].std()
nox_std
# Out:
# 0.36491668491094686

# %%
ptratio_mean=df1["ptratio_log"].mean()
ptratio_mean
# Out:
# 2.907913644905279

# %%
ptratio_std=df1["ptratio_log"].std()
ptratio_std
# Out:
# 0.1248212479008397

# %%
lstat_mean=df1["lstat_sqrt"].mean()
lstat_mean
# Out:
# 3.417673175758353

# %%
lstat_std=df1["lstat_sqrt"].std()
lstat_std
# Out:
# 0.987167256619075

# %%
df1=df1.loc[((df1.rm > (rm_mean - (rm_std*3))) | (df1.rm < (rm_mean + (rm_std*3))) | (df1.age > (age_mean - (age_std*3))) | (df1.age < (age_mean + (age_std*3))) | (df1.dis > (dis_mean - (dis_std*3))) | (df1.dis < (dis_mean + (dis_std*3))) | (df1.black > (black_mean - (black_std*3))) | (df1.black < (black_mean + (black_std*3))) | (df1.crim_sqrt > (crim_mean - (crim_std*3))) | (df1.crim_sqrt < (crim_mean + (crim_std*3))) | (df1.indus_inverse > (indus_mean - (indus_std*3))) | (df1.indus_inverse < (indus_mean + (indus_std*3))) | (df1.nox_inverse > (nox_mean - (nox_std*3))) | (df1.nox_inverse < (nox_mean + (nox_std*3))) | (df1.ptratio_log > (ptratio_mean - (ptratio_std*3))) | (df1.ptratio_log < (ptratio_mean + (ptratio_std*3))) | (df1.lstat_sqrt > (lstat_mean - (lstat_std*3))) | (df1.lstat_sqrt < (lstat_mean + (lstat_std*3))))]

# %%
df1
# Out:
#        zn  chas     rm   age     dis  rad  tax   black  medv  crim_sqrt  \
# 0    18.0     0  6.575  65.2  4.0900    1  296  396.90  24.0   0.079498
# 1     0.0     0  6.421  78.9  4.9671    2  242  396.90  21.6   0.165257
# 2     0.0     0  7.185  61.1  4.9671    2  242  392.83  34.7   0.165197
# 3     0.0     0  6.998  45.8  6.0622    3  222  394.63  33.4   0.179917
# 4     0.0     0  7.147  54.2  6.0622    3  222  396.90  36.2   0.262774
# ..    ...   ...    ...   ...     ...  ...  ...     ...   ...        ...
# 501   0.0     0  6.593  69.1  2.4786    1  273  391.99  22.4   0.250260
# 502   0.0     0  6.120  76.7  2.2875    1  273  396.90  20.6   0.212767
# 503   0.0     0  6.976  91.0  2.1675    1  273  396.90  23.9   0.246495
# 504   0.0     0  6.794  89.3  2.3889    1  273  393.45  22.0   0.331044
# 505   0.0     0  6.030  80.8  2.5050    1  273  396.90  11.9   0.217738
#
#      indus_inverse  nox_inverse  ptratio_log  lstat_sqrt
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()

# %%
df1["zn"]=lb.fit_transform(df1["zn"])

# %%
df1["chas"]=lb.fit_transform(df1["chas"])

# %%
df1["rad"]=lb.fit_transform(df1["rad"])

# %%
df1["tax"]=lb.fit_transform(df["tax"])

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
ssc= StandardScaler()

# %%
df1[["rm","age","dis","black","crim_sqrt","indus_inverse","nox_inverse","ptratio_log","lstat_sqrt","zn","chas","rad","tax"]]=ssc.fit_transform(df1[["rm","age","dis","black","crim_sqrt","indus_inverse","nox_inverse","ptratio_log","lstat_sqrt","zn","chas","rad","tax"]])

# %%
df1
# Out:
#            zn      chas        rm       age       dis       rad       tax  \
# 0    0.004177 -0.272599  0.413672 -0.120013  0.140214 -1.899339 -0.418200
# 1   -0.483571 -0.272599  0.194274  0.367166  0.557160 -1.489678 -1.553761
# 2   -0.483571 -0.272599  1.282714 -0.265812  0.557160 -1.489678 -1.553761
# 3   -0.483571 -0.272599  1.016303 -0.809889  1.077737 -1.080016 -1.849994
# 4   -0.483571 -0.272599  1.228577 -0.511180  1.077737 -1.080016 -1.849994
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.483571 -0.272599  0.439316  0.018673 -0.625796 -1.899339 -0.961294
# 502 -0.483571 -0.272599 -0.234548  0.288933 -0.716639 -1.899339 -0.961294
# 503 -0.483571 -0.272599  0.984960  0.797449 -0.773684 -1.899339 -0.961294
# 504 -0.483571 -0.272599  0.725672  0.736996 -0.668437 -1.899339 -0.961294
# 505 -0.483571 -0.272599 -0.362767  0.434732 -0.613246 -1.899339 -0.961294
#
#         black  medv  crim_sqrt  indus_inverse  nox_inverse  ptratio_log  \
# ...

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # 1) Correlation Matrix

# %%
df1_corr=df1.drop(columns=["zn","chas","rad","tax"])

# %%
df1_corr
# Out:
#            rm       age       dis     black  medv  crim_sqrt  indus_inverse  \
# 0    0.413672 -0.120013  0.140214  0.441052  24.0  -0.793157       1.522898
# 1    0.194274  0.367166  0.557160  0.441052  21.6  -0.734006      -0.119393
# 2    1.282714 -0.265812  0.557160  0.396427  34.7  -0.734047      -0.119393
# 3    1.016303 -0.809889  1.077737  0.416163  33.4  -0.723894       1.668360
# 4    1.228577 -0.511180  1.077737  0.441052  36.2  -0.666745       1.668360
# ..        ...       ...       ...       ...   ...        ...            ...
# 501  0.439316  0.018673 -0.625796  0.387217  22.4  -0.675376      -0.444070
# 502 -0.234548  0.288933 -0.716639  0.441052  20.6  -0.701236      -0.444070
# 503  0.984960  0.797449 -0.773684  0.441052  23.9  -0.677973      -0.444070
# 504  0.725672  0.736996 -0.668437  0.403225  22.0  -0.619657      -0.444070
# 505 -0.362767  0.434732 -0.613246  0.441052  11.9  -0.697807      -0.444070
#
#      nox_inverse  ptratio_log  lstat_sqrt
# ...

# %%
df1corr=df1_corr.corr()
df1corr
# Out:
#                      rm       age       dis     black      medv  crim_sqrt  \
# rm             1.000000 -0.240265  0.205246  0.128069  0.695360  -0.284077
# age           -0.240265  1.000000 -0.747881 -0.273534 -0.376955   0.522481
# dis            0.205246 -0.747881  1.000000  0.291512  0.249929  -0.550683
# black          0.128069 -0.273534  0.291512  1.000000  0.333461  -0.489344
# medv           0.695360 -0.376955  0.249929  0.333461  1.000000  -0.463354
# crim_sqrt     -0.284077  0.522481 -0.550683 -0.489344 -0.463354   1.000000
# indus_inverse  0.374612 -0.464076  0.571717  0.214320  0.439382  -0.389046
# nox_inverse    0.304060 -0.789315  0.836115  0.372255  0.428083  -0.652853
# ptratio_log   -0.356109  0.237448 -0.212920 -0.167595 -0.503160   0.360652
# lstat_sqrt    -0.644529  0.617889 -0.500001 -0.361030 -0.785109   0.572515
#
#                indus_inverse  nox_inverse  ptratio_log  lstat_sqrt
# rm                  0.374612     0.304060    -0.356109   -0.644529
# ...

# %%
sb.heatmap(df1corr)

# %%
df2=df1.drop(columns=["rm","nox_inverse","age","lstat_sqrt"])
df2
# Out:
#            zn      chas       dis       rad       tax     black  medv  \
# 0    0.004177 -0.272599  0.140214 -1.899339 -0.418200  0.441052  24.0
# 1   -0.483571 -0.272599  0.557160 -1.489678 -1.553761  0.441052  21.6
# 2   -0.483571 -0.272599  0.557160 -1.489678 -1.553761  0.396427  34.7
# 3   -0.483571 -0.272599  1.077737 -1.080016 -1.849994  0.416163  33.4
# 4   -0.483571 -0.272599  1.077737 -1.080016 -1.849994  0.441052  36.2
# ..        ...       ...       ...       ...       ...       ...   ...
# 501 -0.483571 -0.272599 -0.625796 -1.899339 -0.961294  0.387217  22.4
# 502 -0.483571 -0.272599 -0.716639 -1.899339 -0.961294  0.441052  20.6
# 503 -0.483571 -0.272599 -0.773684 -1.899339 -0.961294  0.441052  23.9
# 504 -0.483571 -0.272599 -0.668437 -1.899339 -0.961294  0.403225  22.0
# 505 -0.483571 -0.272599 -0.613246 -1.899339 -0.961294  0.441052  11.9
#
#      crim_sqrt  indus_inverse  ptratio_log
# 0    -0.793157       1.522898    -1.443977
# ...

# %% [markdown]
# # 2) Anova Test

# %%
df_cat=df1.loc[:,["zn","chas","rad","tax","medv"]]
df_cat
# Out:
#            zn      chas       rad       tax  medv
# 0    0.004177 -0.272599 -1.899339 -0.418200  24.0
# 1   -0.483571 -0.272599 -1.489678 -1.553761  21.6
# 2   -0.483571 -0.272599 -1.489678 -1.553761  34.7
# 3   -0.483571 -0.272599 -1.080016 -1.849994  33.4
# 4   -0.483571 -0.272599 -1.080016 -1.849994  36.2
# ..        ...       ...       ...       ...   ...
# 501 -0.483571 -0.272599 -1.899339 -0.961294  22.4
# 502 -0.483571 -0.272599 -1.899339 -0.961294  20.6
# 503 -0.483571 -0.272599 -1.899339 -0.961294  23.9
# 504 -0.483571 -0.272599 -1.899339 -0.961294  22.0
# 505 -0.483571 -0.272599 -1.899339 -0.961294  11.9
#
# [506 rows x 5 columns]

# %%
from scipy.stats import f_oneway

# %%
print(f_oneway(df_cat.medv,df_cat.zn))
print(f_oneway(df_cat.medv,df_cat.chas))
print(f_oneway(df_cat.medv,df_cat.rad))
print(f_oneway(df_cat.medv,df_cat.tax))
# Out:
# F_onewayResult(statistic=3001.681684641177, pvalue=9.224378046831598e-305)
# F_onewayResult(statistic=3001.681684641171, pvalue=9.224378046838937e-305)
# F_onewayResult(statistic=3001.681684641175, pvalue=9.224378046834742e-305)
# F_onewayResult(statistic=3001.681684641177, pvalue=9.224378046831598e-305)

# %%
df3=df1.drop(columns=["rm","nox_inverse","age","lstat_sqrt","zn","chas","rad","tax"])
df3
# Out:
#           dis     black  medv  crim_sqrt  indus_inverse  ptratio_log
# 0    0.140214  0.441052  24.0  -0.793157       1.522898    -1.443977
# 1    0.557160  0.441052  21.6  -0.734006      -0.119393    -0.230278
# 2    0.557160  0.396427  34.7  -0.734047      -0.119393    -0.230278
# 3    1.077737  0.416163  33.4  -0.723894       1.668360     0.165279
# 4    1.077737  0.441052  36.2  -0.666745       1.668360     0.165279
# ..        ...       ...   ...        ...            ...          ...
# 501 -0.625796  0.387217  22.4  -0.675376      -0.444070     1.095518
# 502 -0.716639  0.441052  20.6  -0.701236      -0.444070     1.095518
# 503 -0.773684  0.441052  23.9  -0.677973      -0.444070     1.095518
# 504 -0.668437  0.403225  22.0  -0.619657      -0.444070     1.095518
# 505 -0.613246  0.441052  11.9  -0.697807      -0.444070     1.095518
#
# [506 rows x 6 columns]

# %% [markdown]
# # Train Test Split

# %%
x=df3.drop(columns=["medv"])
x
# Out:
#           dis     black  crim_sqrt  indus_inverse  ptratio_log
# 0    0.140214  0.441052  -0.793157       1.522898    -1.443977
# 1    0.557160  0.441052  -0.734006      -0.119393    -0.230278
# 2    0.557160  0.396427  -0.734047      -0.119393    -0.230278
# 3    1.077737  0.416163  -0.723894       1.668360     0.165279
# 4    1.077737  0.441052  -0.666745       1.668360     0.165279
# ..        ...       ...        ...            ...          ...
# 501 -0.625796  0.387217  -0.675376      -0.444070     1.095518
# 502 -0.716639  0.441052  -0.701236      -0.444070     1.095518
# 503 -0.773684  0.441052  -0.677973      -0.444070     1.095518
# 504 -0.668437  0.403225  -0.619657      -0.444070     1.095518
# 505 -0.613246  0.441052  -0.697807      -0.444070     1.095518
#
# [506 rows x 5 columns]

# %%
y=df3.loc[:,"medv"]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#           dis     black  crim_sqrt  indus_inverse  ptratio_log
# 220 -0.443682  0.384037  -0.435247      -0.007557    -0.412545
# 71   0.709373  0.222203  -0.573166      -0.395134     0.376884
# 240  1.207940  0.379103  -0.615834       0.226564    -0.789997
# 6    0.839244  0.426798  -0.643044      -0.200409    -1.496563
# 417 -1.020876 -2.514281   2.664972      -0.605075     0.784047
# ..        ...       ...        ...            ...          ...
# 323  0.440219  0.377788  -0.480469      -0.152871     0.542238
# 192  1.276251  0.370770  -0.644968       0.721621    -1.496563
# 117 -0.498017  0.414847  -0.579984      -0.353475    -0.230278
# 47   0.900519  0.395440  -0.517729      -0.100939    -0.185351
# 172 -0.569940  0.441052  -0.590708       0.474909    -0.789997
#
# [404 rows x 5 columns]

# %%
x_test
# Out:
#           dis     black  crim_sqrt  indus_inverse  ptratio_log
# 329  0.674814  0.203235  -0.669136       0.822733    -0.646363
# 371 -1.248292  0.103898   1.247755      -0.605075     0.784047
# 219 -0.205237  0.406405  -0.614852      -0.510718    -0.887203
# 403 -0.994588  0.441052   2.586990      -0.605075     0.784047
# 78   0.579502  0.325926  -0.684099      -0.477202     0.165279
# ..        ...       ...        ...            ...          ...
# 56   2.563455  0.441052  -0.749114       6.698139    -0.458766
# 455 -0.646142 -3.352397   0.655632      -0.605075     0.784047
# 60   1.630686  0.421426  -0.581462       0.182004     0.583049
# 213  0.071475  0.319457  -0.589435      -0.384305     0.122279
# 108 -0.647521  0.422851  -0.601203      -0.258122     1.057240
#
# [102 rows x 5 columns]

# %%
y_train
# Out:
# 220    26.7
# 71     21.7
# 240    22.0
# 6      22.9
# 417    10.4
#        ...
# 323    18.5
# 192    36.4
# 117    19.2
# 47     16.6
# 172    23.1
# Name: medv, Length: 404, dtype: float64

# %%
y_test
# Out:
# 329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: medv, Length: 102, dtype: float64

# %% [markdown]
# # Applying Linear Regression & R-Square Metric

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([27.99242631, 16.86771282, 26.22492929, 13.61782728, 21.9494111 ,
#        19.20484318, 17.39767989, 22.11326925, 21.3768697 , 15.93608614,
#         1.46176632, 10.32489242, 16.47546489, 13.84024384, 27.71399561,
#        31.97496533, 16.98372239, 40.36045313, 29.01990206, 23.51381108,
#        21.84676935, 26.56442243, 21.37706284, 25.42987077, 23.96636761,
#        11.93747741, 19.24080438, 25.82888616, 28.26077019, 24.91151013,
#        16.15512581, 17.09742391, 20.45919243, 26.18588794, 29.32268314,
#        17.90787009, 13.64820594, 16.89687583, 12.18311521, 16.11949988,
#        25.62468463, 23.93159691, 27.54900655, 16.20095775, 32.89916621,
#        24.57533784, 24.94816534, 27.13603816, 27.72563953, 21.0251681 ,
#        22.36223511, 22.88481893, 25.04228384, 19.94705856, 16.69757112,
#        27.75117803, 25.0785576 , 21.99153143,  3.9779705 , 22.87678047,
#        27.30354086, 22.75535026, 26.83373352, 25.38116731, 15.27477103,
# ...

# %%
from sklearn.metrics import r2_score as rs

# %%
score=rs(y_test,y_pred)

# %%
score
# Out:
# 0.009282336003876845

# %%
rmse=(((y_test-y_pred)**2).mean())**(1/2)

# %%
rmse
# Out:
# 8.981792300552017
