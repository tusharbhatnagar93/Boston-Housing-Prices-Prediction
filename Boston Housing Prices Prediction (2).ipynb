# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv(r"C:\Users\manasbhatnagar\Downloads\bostonhousing.csv")

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df=df.drop(columns=["Unnamed: 0"])
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # EDA

# %%
sb.distplot(df["crim"])

# %%
sb.distplot(df["zn"])

# %%
sb.distplot(df["indus"])

# %%
sb.distplot(df["chas"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-289-8be577557472> in <module>
# ----> 1 sb.distplot(df["chas"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# --> 233         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     234         if kde_color != color:
#     235             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     704                                  gridsize, cut, clip, legend, ax,
# --> 705                                  cumulative=cumulative, **kwargs)
#     706
#     707     return ax
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     293         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     294                                            gridsize, cut, clip,
# --> 295                                            cumulative=cumulative)
#     296     else:
#     297         # Fall back to scipy if missing statsmodels
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     365     fft = kernel == "gau"
#     366     kde = smnp.KDEUnivariate(data)
# --> 367     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     368     if cumulative:
#     369         grid, y = kde.support, kde.cdf
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     138             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     139                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 140                     clip=clip, cut=cut)
#     141         else:
#     142             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     451         bw = float(bw)
#     452     except:
# --> 453         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     454     bw *= adjust
#     455
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     172         # eventually this can fall back on another selection criterion.
#     173         err = "Selected KDE bandwidth is 0. Cannot estiamte density."
# --> 174         raise RuntimeError(err)
#     175     else:
#     176         return bandwidth
#
# RuntimeError: Selected KDE bandwidth is 0. Cannot estiamte density.

# %%
sb.distplot(df["nox"])

# %%
sb.distplot(df["rm"])

# %%
sb.distplot(df["age"])

# %%
sb.distplot(df["dis"])

# %%
sb.distplot(df["rad"])

# %%
sb.distplot(df["tax"])

# %%
sb.distplot(df['ptratio'])

# %%
sb.distplot(df['black'])

# %%
sb.distplot(df['lstat'])

# %%
sb.distplot(df["medv"])

# %%
sb.scatterplot(x="zn",y="medv",data=df)

# %%
sb.scatterplot(x="chas",y="medv",data=df)

# %%
sb.scatterplot(x="rad",y="medv",data=df)

# %%
sb.scatterplot(x="tax",y="medv",data=df)

# %%
sb.pairplot(df)

# %% [markdown]
# # Feature Engineering

# %%
categorical_features=[features for features in df.columns if df[features].dtype=='O']
categorical_features
# Out:
# []

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
sb.distplot(df["lstat"])

# %%
df["lstat_sqrt"]=df["lstat"]**(1/2)

# %%
sb.distplot(df["lstat_sqrt"])

# %%
sb.distplot(df['ptratio'])

# %%
df["ptratio_log"]=np.log(df["ptratio"])

# %%
sb.distplot(df["ptratio_log"])

# %%
sb.distplot(df["indus"])

# %%
df["indus_inverse"]=1/df["indus"]

# %%
sb.distplot(df["indus_inverse"])

# %%
sb.distplot(df["nox"])

# %%
df["nox_inverse"]=1/df["nox"]

# %%
sb.distplot(df["nox_inverse"])

# %%
df["crim_sqrt"]=df["crim"]**(1/2)

# %%
sb.distplot(df["crim_sqrt"])

# %%
df1=df.drop(columns=["crim","indus","nox","ptratio","lstat"])

# %%
df1
# Out:
#        zn  chas     rm   age     dis  rad  tax   black  medv  lstat_sqrt  \
# 0    18.0     0  6.575  65.2  4.0900    1  296  396.90  24.0    2.231591
# 1     0.0     0  6.421  78.9  4.9671    2  242  396.90  21.6    3.023243
# 2     0.0     0  7.185  61.1  4.9671    2  242  392.83  34.7    2.007486
# 3     0.0     0  6.998  45.8  6.0622    3  222  394.63  33.4    1.714643
# 4     0.0     0  7.147  54.2  6.0622    3  222  396.90  36.2    2.308679
# ..    ...   ...    ...   ...     ...  ...  ...     ...   ...         ...
# 501   0.0     0  6.593  69.1  2.4786    1  273  391.99  22.4    3.109662
# 502   0.0     0  6.120  76.7  2.2875    1  273  396.90  20.6    3.013304
# 503   0.0     0  6.976  91.0  2.1675    1  273  396.90  23.9    2.374868
# 504   0.0     0  6.794  89.3  2.3889    1  273  393.45  22.0    2.545584
# 505   0.0     0  6.030  80.8  2.5050    1  273  396.90  11.9    2.807134
#
#      ptratio_log  indus_inverse  nox_inverse  crim_sqrt
# 0       2.727853       0.432900     1.858736   0.079498
# 1       2.879198       0.141443     2.132196   0.165257
# 2       2.879198       0.141443     2.132196   0.165197
# 3       2.928524       0.458716     2.183406   0.179917
# 4       2.928524       0.458716     2.183406   0.262774
# ..           ...            ...          ...        ...
# 501     3.044522       0.083822     1.745201   0.250260
# 502     3.044522       0.083822     1.745201   0.212767
# 503     3.044522       0.083822     1.745201   0.246495
# 504     3.044522       0.083822     1.745201   0.331044
# 505     3.044522       0.083822     1.745201   0.217738
#
# [506 rows x 14 columns]

# %% [markdown]
# # Outlier Detection & Removal

# %%
rm_mean=df1["rm"].mean()
rm_mean
# Out:
# 6.284634387351788

# %%
rm_std=df1["rm"].std()
rm_std
# Out:
# 0.7026171434153234

# %%
age_mean=df1["age"].mean()
age_mean
# Out:
# 68.57490118577078

# %%
age_std=df1["age"].std()
age_std
# Out:
# 28.148861406903638

# %%
dis_mean=df1["dis"].mean()
dis_mean
# Out:
# 3.795042687747034

# %%
dis_std=df1["dis"].std()
dis_std
# Out:
# 2.1057101266276104

# %%
black_mean=df1["black"].mean()
black_mean
# Out:
# 356.67403162055257

# %%
black_std=df1["black"].std()
black_std
# Out:
# 91.29486438415779

# %%
crim_mean=df1["crim_sqrt"].mean()
crim_mean
# Out:
# 1.2294394198092045

# %%
crim_std=df1["crim_sqrt"].std()
crim_std
# Out:
# 1.4512631226158779

# %%
indus_mean=df1["indus_inverse"].mean()
indus_mean
# Out:
# 0.16263141886673582

# %%
indus_std=df1["indus_inverse"].std()
indus_std
# Out:
# 0.1776458174936309

# %%
nox_mean=df1["nox_inverse"].mean()
nox_mean
# Out:
# 1.8771452603098617

# %%
nox_std=df1["nox_inverse"].std()
nox_std
# Out:
# 0.36491668491094686

# %%
ptratio_mean=df1["ptratio_log"].mean()
ptratio_mean
# Out:
# 2.907913644905279

# %%
ptratio_std=df1["ptratio_log"].std()
ptratio_std
# Out:
# 0.1248212479008397

# %%
lstat_mean=df1["lstat_sqrt"].mean()
lstat_mean
# Out:
# 3.417673175758353

# %%
lstat_std=df1["lstat_sqrt"].std()
lstat_std
# Out:
# 0.987167256619075

# %%
df1=df1.loc[((df1.rm > (rm_mean - (rm_std*3))) | (df1.rm < (rm_mean + (rm_std*3))) | (df1.age > (age_mean - (age_std*3))) | (df1.age < (age_mean + (age_std*3))) | (df1.dis > (dis_mean - (dis_std*3))) | (df1.dis < (dis_mean + (dis_std*3))) | (df1.black > (black_mean - (black_std*3))) | (df1.black < (black_mean + (black_std*3))) | (df1.crim_sqrt > (crim_mean - (crim_std*3))) | (df1.crim_sqrt < (crim_mean + (crim_std*3))) | (df1.indus_inverse > (indus_mean - (indus_std*3))) | (df1.indus_inverse < (indus_mean + (indus_std*3))) | (df1.nox_inverse > (nox_mean - (nox_std*3))) | (df1.nox_inverse < (nox_mean + (nox_std*3))) | (df1.ptratio_log > (ptratio_mean - (ptratio_std*3))) | (df1.ptratio_log < (ptratio_mean + (ptratio_std*3))) | (df1.lstat_sqrt > (lstat_mean - (lstat_std*3))) | (df1.lstat_sqrt < (lstat_mean + (lstat_std*3))))]

# %%
df1
# Out:
#        zn  chas     rm   age     dis  rad  tax   black  medv  crim_sqrt  \
# 0    18.0     0  6.575  65.2  4.0900    1  296  396.90  24.0   0.079498
# 1     0.0     0  6.421  78.9  4.9671    2  242  396.90  21.6   0.165257
# 2     0.0     0  7.185  61.1  4.9671    2  242  392.83  34.7   0.165197
# 3     0.0     0  6.998  45.8  6.0622    3  222  394.63  33.4   0.179917
# 4     0.0     0  7.147  54.2  6.0622    3  222  396.90  36.2   0.262774
# ..    ...   ...    ...   ...     ...  ...  ...     ...   ...        ...
# 501   0.0     0  6.593  69.1  2.4786    1  273  391.99  22.4   0.250260
# 502   0.0     0  6.120  76.7  2.2875    1  273  396.90  20.6   0.212767
# 503   0.0     0  6.976  91.0  2.1675    1  273  396.90  23.9   0.246495
# 504   0.0     0  6.794  89.3  2.3889    1  273  393.45  22.0   0.331044
# 505   0.0     0  6.030  80.8  2.5050    1  273  396.90  11.9   0.217738
#
#      indus_inverse  nox_inverse  ptratio_log  lstat_sqrt
# 0         0.432900     1.858736     2.727853    2.231591
# 1         0.141443     2.132196     2.879198    3.023243
# 2         0.141443     2.132196     2.879198    2.007486
# 3         0.458716     2.183406     2.928524    1.714643
# 4         0.458716     2.183406     2.928524    2.308679
# ..             ...          ...          ...         ...
# 501       0.083822     1.745201     3.044522    3.109662
# 502       0.083822     1.745201     3.044522    3.013304
# 503       0.083822     1.745201     3.044522    2.374868
# 504       0.083822     1.745201     3.044522    2.545584
# 505       0.083822     1.745201     3.044522    2.807134
#
# [506 rows x 14 columns]

# %%
categorical_features=[feature for feature in df1.columns if df[feature].dtype=='O']
categorical_features
# Out:
# []

# %%
df1.columns
# Out:
# Index(['zn', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'black', 'medv',
#        'crim_sqrt', 'indus_inverse', 'nox_inverse', 'ptratio_log',
#        'lstat_sqrt'],
#       dtype='object')

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()

# %%
df1[['zn', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'black','crim_sqrt', 'indus_inverse', 'nox_inverse', 'ptratio_log','lstat_sqrt']]=mms.fit_transform(df1[['zn', 'chas', 'rm', 'age', 'dis', 'rad', 'tax', 'black','crim_sqrt', 'indus_inverse', 'nox_inverse', 'ptratio_log','lstat_sqrt']])

# %%
df1
# Out:
#        zn  chas        rm       age       dis       rad       tax     black  \
# 0    0.18   0.0  0.577505  0.641607  0.269203  0.000000  0.208015  1.000000
# 1    0.00   0.0  0.547998  0.782698  0.348962  0.043478  0.104962  1.000000
# 2    0.00   0.0  0.694386  0.599382  0.348962  0.043478  0.104962  0.989737
# 3    0.00   0.0  0.658555  0.441813  0.448545  0.086957  0.066794  0.994276
# 4    0.00   0.0  0.687105  0.528321  0.448545  0.086957  0.066794  1.000000
# ..    ...   ...       ...       ...       ...       ...       ...       ...
# 501  0.00   0.0  0.580954  0.681771  0.122671  0.000000  0.164122  0.987619
# 502  0.00   0.0  0.490324  0.760041  0.105293  0.000000  0.164122  1.000000
# 503  0.00   0.0  0.654340  0.907312  0.094381  0.000000  0.164122  1.000000
# 504  0.00   0.0  0.619467  0.889804  0.114514  0.000000  0.164122  0.991301
# 505  0.00   0.0  0.473079  0.802266  0.125072  0.000000  0.164122  1.000000
#
#      medv  lstat_sqrt  ptratio_log  indus_inverse  nox_inverse  crim_sqrt
# 0    24.0    0.189056     0.348358       0.185630     0.490328   0.000000
# 1    21.6    0.352395     0.619906       0.049299     0.679012   0.009169
# 2    34.7    0.142817     0.619906       0.049299     0.679012   0.009162
# 3    33.4    0.082396     0.708405       0.197705     0.714347   0.010736
# 4    36.2    0.204962     0.708405       0.197705     0.714347   0.019595
# ..    ...         ...          ...            ...          ...        ...
# 501  22.4    0.370226     0.916533       0.022346     0.411989   0.018257
# 502  20.6    0.350344     0.916533       0.022346     0.411989   0.014248
# 503  23.9    0.218618     0.916533       0.022346     0.411989   0.017854
# 504  22.0    0.253841     0.916533       0.022346     0.411989   0.026894
# 505  11.9    0.307806     0.916533       0.022346     0.411989   0.014780
#
# [506 rows x 14 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # 1) Correlation Matrix

# %%
cor=df1.corr()

# %%
cor
# Out:
#                      zn      chas        rm       age       dis       rad  \
# zn             1.000000 -0.042697  0.311991 -0.569537  0.664408 -0.311948
# chas          -0.042697  1.000000  0.091251  0.086518 -0.099176 -0.007368
# rm             0.311991  0.091251  1.000000 -0.240265  0.205246 -0.209847
# age           -0.569537  0.086518 -0.240265  1.000000 -0.747881  0.456022
# dis            0.664408 -0.099176  0.205246 -0.747881  1.000000 -0.494588
# rad           -0.311948 -0.007368 -0.209847  0.456022 -0.494588  1.000000
# tax           -0.314563 -0.035587 -0.292048  0.506456 -0.534432  0.910228
# black          0.175520  0.048788  0.128069 -0.273534  0.291512 -0.444413
# medv           0.360445  0.175260  0.695360 -0.376955  0.249929 -0.381626
# lstat_sqrt    -0.452250 -0.061929 -0.644529  0.617889 -0.500001  0.484826
# ptratio_log   -0.390312 -0.116495 -0.356109  0.237448 -0.212920  0.452456
# indus_inverse  0.654859 -0.066528  0.374612 -0.464076  0.571717 -0.390400
# nox_inverse    0.616544 -0.076486  0.304060 -0.789315  0.836115 -0.625000
# crim_sqrt     -0.331274 -0.030148 -0.284077  0.522481 -0.550683  0.846998
#
#                     tax     black      medv  lstat_sqrt  ptratio_log  \
# zn            -0.314563  0.175520  0.360445   -0.452250    -0.390312
# chas          -0.035587  0.048788  0.175260   -0.061929    -0.116495
# rm            -0.292048  0.128069  0.695360   -0.644529    -0.356109
# age            0.506456 -0.273534 -0.376955    0.617889     0.237448
# dis           -0.534432  0.291512  0.249929   -0.500001    -0.212920
# rad            0.910228 -0.444413 -0.381626    0.484826     0.452456
# tax            1.000000 -0.441808 -0.468536    0.544771     0.443642
# black         -0.441808  1.000000  0.333461   -0.361030    -0.167595
# medv          -0.468536  0.333461  1.000000   -0.785109    -0.503160
# lstat_sqrt     0.544771 -0.361030 -0.785109    1.000000     0.388095
# ptratio_log    0.443642 -0.167595 -0.503160    0.388095     1.000000
# indus_inverse -0.424119  0.214320  0.439382   -0.478580    -0.361695
# nox_inverse   -0.673917  0.372255  0.428083   -0.613632    -0.236009
# crim_sqrt      0.801714 -0.489344 -0.463354    0.572515     0.360652
#
#                indus_inverse  nox_inverse  crim_sqrt
# zn                  0.654859     0.616544  -0.331274
# chas               -0.066528    -0.076486  -0.030148
# rm                  0.374612     0.304060  -0.284077
# age                -0.464076    -0.789315   0.522481
# dis                 0.571717     0.836115  -0.550683
# rad                -0.390400    -0.625000   0.846998
# tax                -0.424119    -0.673917   0.801714
# black               0.214320     0.372255  -0.489344
# medv                0.439382     0.428083  -0.463354
# lstat_sqrt         -0.478580    -0.613632   0.572515
# ptratio_log        -0.361695    -0.236009   0.360652
# indus_inverse       1.000000     0.566089  -0.389046
# nox_inverse         0.566089     1.000000  -0.652853
# crim_sqrt          -0.389046    -0.652853   1.000000

# %%
sb.heatmap(cor)

# %%
df2=df1.drop(columns=["tax","zn","chas","lstat_sqrt","rm","nox_inverse","crim_sqrt","ptratio_log","indus_inverse"])
df2
# Out:
#           age       dis       rad     black  medv
# 0    0.641607  0.269203  0.000000  1.000000  24.0
# 1    0.782698  0.348962  0.043478  1.000000  21.6
# 2    0.599382  0.348962  0.043478  0.989737  34.7
# 3    0.441813  0.448545  0.086957  0.994276  33.4
# 4    0.528321  0.448545  0.086957  1.000000  36.2
# ..        ...       ...       ...       ...   ...
# 501  0.681771  0.122671  0.000000  0.987619  22.4
# 502  0.760041  0.105293  0.000000  1.000000  20.6
# 503  0.907312  0.094381  0.000000  1.000000  23.9
# 504  0.889804  0.114514  0.000000  0.991301  22.0
# 505  0.802266  0.125072  0.000000  1.000000  11.9
#
# [506 rows x 5 columns]

# %% [markdown]
# # Train Test Split

# %%
x=df2.drop(columns=["medv"])
x
# Out:
#           age       dis       rad     black
# 0    0.641607  0.269203  0.000000  1.000000
# 1    0.782698  0.348962  0.043478  1.000000
# 2    0.599382  0.348962  0.043478  0.989737
# 3    0.441813  0.448545  0.086957  0.994276
# 4    0.528321  0.448545  0.086957  1.000000
# ..        ...       ...       ...       ...
# 501  0.681771  0.122671  0.000000  0.987619
# 502  0.760041  0.105293  0.000000  1.000000
# 503  0.907312  0.094381  0.000000  1.000000
# 504  0.889804  0.114514  0.000000  0.991301
# 505  0.802266  0.125072  0.000000  1.000000
#
# [506 rows x 4 columns]

# %%
y=df2.loc[:,"medv"]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#           age       dis       rad     black
# 220  0.881565  0.157508  0.304348  0.986888
# 71   0.150360  0.378079  0.130435  0.949670
# 240  0.529351  0.473452  0.217391  0.985753
# 6    0.656025  0.402923  0.173913  0.996722
# 417  0.887745  0.047095  1.000000  0.320339
# ..        ...       ...       ...       ...
# 323  0.735324  0.326592  0.173913  0.985451
# 192  0.240989  0.486519  0.173913  0.983837
# 117  0.820803  0.147114  0.217391  0.993973
# 47   0.850669  0.414644  0.086957  0.989510
# 172  0.881565  0.133356  0.173913  1.000000
#
# [404 rows x 4 columns]

# %%
x_test
# Out:
#           age       dis       rad     black
# 329  0.147271  0.371468  0.130435  0.945307
# 371  1.000000  0.003592  1.000000  0.922462
# 219  0.921730  0.203121  0.173913  0.992032
# 403  0.958805  0.052124  1.000000  1.000000
# 78   0.523172  0.353236  0.173913  0.973524
# ..        ...       ...       ...       ...
# 56   0.337796  0.732752  0.043478  1.000000
# 455  0.860968  0.118779  1.000000  0.127591
# 60   0.651905  0.554320  0.304348  0.995486
# 213  0.302781  0.256054  0.130435  0.972036
# 108  0.970134  0.118515  0.173913  0.995814
#
# [102 rows x 4 columns]

# %%
y_train
# Out:
# 220    26.7
# 71     21.7
# 240    22.0
# 6      22.9
# 417    10.4
#        ...
# 323    18.5
# 192    36.4
# 117    19.2
# 47     16.6
# 172    23.1
# Name: medv, Length: 404, dtype: float64

# %%
y_test
# Out:
# 329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: medv, Length: 102, dtype: float64

# %% [markdown]
# # Applying Linear Regression & R-Square Metric

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([29.92907592, 16.95725717, 21.81591251, 17.63548181, 25.29944468,
#        25.83114798, 21.79745828, 25.05595298, 29.05180966, 16.8474152 ,
#         9.45215648, 10.05706611, 15.69748265, 17.31568738, 22.10593961,
#        28.29368639, 20.24198625, 26.92313854, 29.67488325, 28.01661515,
#        26.09446747, 21.10031564, 23.68993293, 29.33747627, 28.5711919 ,
#        11.99094073, 21.92834757, 19.87999087, 24.72025678, 21.9100662 ,
#        16.80322351, 18.28041607, 18.63825656, 22.57977734, 23.54218127,
#        17.50083252, 17.21206009, 17.98050988, 12.38249896, 15.14939951,
#        29.95940171, 28.63626344, 27.28307749, 16.21126547, 24.6144766 ,
#        23.08849151, 24.10923449, 21.27434198, 22.89530438, 23.96197901,
#        18.38055047, 30.29213106, 23.58974504, 27.54048745, 19.56632402,
#        26.92197048, 28.45026919, 23.0377778 ,  9.50831218, 21.68049061,
#        25.4174566 , 25.96725552, 29.11154555, 29.95965441, 21.79487579,
#        28.81133058, 15.96441591, 19.00189327, 12.98423126, 30.7789718 ,
#        23.15844609, 26.80444952, 29.09257032, 27.42558315, 18.91707027,
#        18.63855712, 23.31906969, 26.45924284, 26.2580121 , 24.84386176,
#        25.46873681, 22.60478214, 16.17991879, 23.05797766, 22.38555611,
#        28.39371599, 25.45218952, 14.6940692 , 21.60194732, 18.62726468,
#        24.88393427, 11.74075287, 25.76091691, 23.81034942, 25.21257081,
#        24.68323979, 17.59708319, 25.1139703 , 11.35604061, 21.14221141,
#        29.25665334, 22.02700177])

# %%
from sklearn.metrics import r2_score as rs

# %%
score=rs(y_test,y_pred)

# %%
score
# Out:
# 0.02381517861267768

# %%
rmse=(((y_test-y_pred)**2).mean())**(1/2)

# %%
rmse
# Out:
# 8.91567194559606

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train